# %%
import numpy as np
from sklearn.svm import SVR
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
X = np.sort(5 * np.random.rand(40, 1), axis=0)
y = (X ** 4 - 4 * (X ** 3) - 3 * (X ** 2) +  2 * X + 3).ravel()
y[::5] += 100 * (0.5 - np.random.rand(8))

# %%
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly2 = SVR(kernel='poly', C=1e3, degree=2)
svr_poly4 = SVR(kernel='poly', C=1e3, degree=4)
y_rbf = svr_rbf.fit(X, y).predict(X)
y_lin = svr_lin.fit(X, y).predict(X)
y_poly2 = svr_poly2.fit(X, y).predict(X)
y_poly4 = svr_poly4.fit(X, y).predict(X)

# %%
lw = 2
plt.scatter(X, y, color='darkorange', label='data')
plt.plot(X, y_rbf, color='navy', lw=lw, label='RBF model')
plt.plot(X, y_lin, color='c', lw=lw, label='Linear model')
plt.plot(X, y_poly2, color='cornflowerblue', lw=lw, label='Polynomial model dim 2')
plt.plot(X, y_poly4, color='blue', lw=lw, label='Polynomial model dim 4')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()
plt.show()
